# %%
def ler_arquivo_texto(caminho_arquivo):
    with open(caminho_arquivo, 'r', encoding='utf-8') as arquivo:
        linhas = arquivo.readlines()
    return [linha.strip() for linha in linhas]

# %%
arquivo = ler_arquivo_texto('pux_vel_.csv')

# %%
type(arquivo)
# Out:
# list

# %%
for linha in arquivo:
    print(linha)
# Out:
# "Date , Vehicle , Driver , Odometer  (Km ), Duration , Speed  (Km/h ), Maximum RPM , Event Type , Event Description , Limit  (Km/h )"
# "05/03/2025 08:20:06 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561865.7, 00:00:15, 86, 1996, Speeding (dry) , Speeding - Highway dry , 80"
# "05/03/2025 08:15:30 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561860.2, 00:00:19, 84, 2008, Speeding (dry) , Speeding - Highway dry , 80"
# "05/03/2025 08:14:03 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561858.6, 00:01:24, 87, 1365, Speeding (dry) , Speeding - Highway dry , 80"
# "05/03/2025 08:11:50 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561855.6, 00:00:30, 90, 2177, Speeding (dry) , Speeding - Highway dry , 80"
# "05/03/2025 08:11:04 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561854.6, 00:00:54, 88, 1373, Speeding (dry) , Speeding - Highway dry , 80"
# ...

# %%
with open('pux_vel_.csv', 'r', encoding='utf-8') as arquivo_csv:
    leitor_csv = csv.reader(arquivo_csv)

    dados = list(leitor_csv)

# %%
lista = []

lista_2 = list()

# %%
meu_nome = 'Anderson Barboza da Cruz'
letras = []
for letra in meu_nome:
    print(letra)
    lista.append(letra)
    
letras
# Out:
# A
# n
# d
# e
# r
# s
# o
# n
#
# B
# a
# r
# b
# o
# z
# a
#
# d
# a
#
# C
# r
# u
# z
# []

# %%
meu_nome = 'Anderson Barboza da Cruz'
letras = list(meu_nome)
letras
# Out:
# ['A',
#  'n',
#  'd',
#  'e',
#  'r',
#  's',
#  'o',
#  'n',
#  ' ',
#  'B',
#  'a',
#  'r',
#  'b',
#  'o',
#  'z',
#  'a',
#  ' ',
#  'd',
#  'a',
#  ' ',
#  'C',
#  'r',
#  'u',
#  'z']

# %%
import csv

# %%
with open('pux_vel_.csv', 'r', encoding='utf-8') as arquivo_csv:
    leitor_csv = csv.reader(arquivo_csv)

    dados = list(leitor_csv)

# %%
type(dados)
# Out:
# list

# %%
dados[0]
# Out:
# ['Date , Vehicle , Driver , Odometer  (Km ), Duration , Speed  (Km/h ), Maximum RPM , Event Type , Event Description , Limit  (Km/h )']

# %%
dados[1]
# Out:
# ['05/03/2025 08:20:06 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561865.7, 00:00:15, 86, 1996, Speeding (dry) , Speeding - Highway dry , 80']

# %%
dados[2]
# Out:
# ['05/03/2025 08:15:30 (UTC-3), RTJ2F79, ERIVELTON MIRANDA DA SILVA, 561860.2, 00:00:19, 84, 2008, Speeding (dry) , Speeding - Highway dry , 80']
